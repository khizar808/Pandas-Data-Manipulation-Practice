# %% [markdown]
# # Pandas Libraray

# %%
import pandas as pd

# %%
bk = pd.read_csv(r'C:\Users\HP\OneDrive\Desktop\book.csv')

# %%
bk.head()
# Out:
#    Gender  Age  Occupation  Annual Income  Needle Stick Injuries  \
# 0       2    2           2              3                   4.25
# 1       1    3           1              5                   3.75
# 2       2    1           1              5                   4.00
# 3       2    2           1              4                   4.25
# 4       1    2           1              5                   4.75
#
#    Knowledge and Training on Needle Stick Injury Prevention  \
# 0                                               4.75
# 1                                               4.00
# 2                                               4.00
# 3                                               3.75
# 4                                               2.75
#
#    Availability of Safety Equipment  Adherence to Safety Protocols  \
# 0                               4.0                           4.00
# 1                               4.0                           3.75
# ...

# %%
bk.tail()
# Out:
#     Gender  Age  Occupation  Annual Income  Needle Stick Injuries  \
# 95       1    2           1              5                    2.0
# 96       1    3           2              4                    4.0
# 97       1    2           2              5                    5.0
# 98       2    1           2              3                    3.0
# 99       2    2           2              5                    5.0
#
#     Knowledge and Training on Needle Stick Injury Prevention  \
# 95                                                4.5
# 96                                                4.0
# 97                                                4.0
# 98                                                3.0
# 99                                                5.0
#
#     Availability of Safety Equipment  Adherence to Safety Protocols  \
# 95                              4.25                           2.75
# 96                              4.00                           4.25
# ...

# %%
bk.shape
# Out:
# (100, 9)

# %%
bk.describe()
# Out:
#            Gender         Age  Occupation  Annual Income  \
# count  100.000000  100.000000  100.000000     100.000000
# mean     1.540000    2.190000    1.680000       3.720000
# std      0.500908    0.906709    0.566399       1.247867
# min      1.000000    1.000000    1.000000       1.000000
# 25%      1.000000    2.000000    1.000000       3.000000
# 50%      2.000000    2.000000    2.000000       4.000000
# 75%      2.000000    3.000000    2.000000       5.000000
# max      2.000000    5.000000    3.000000       5.000000
#
#        Needle Stick Injuries  \
# count             100.000000
# mean                3.755000
# std                 1.155236
# min                 1.000000
# 25%                 3.375000
# 50%                 4.000000
# 75%                 4.500000
# max                 5.000000
#
#        Knowledge and Training on Needle Stick Injury Prevention  \
# count                                         100.000000
# ...

# %%
bk.iloc[5:11,0:4]
# Out:
#     Gender  Age  Occupation  Annual Income
# 5        1    3           2              5
# 6        1    2           2              5
# 7        2    1           2              4
# 8        2    2           2              5
# 9        2    2           1              3
# 10       2    2           1              4

# %%
bk.loc[0:10,("Annual Income", "Occupation")]
# Out:
#     Annual Income  Occupation
# 0               3           2
# 1               5           1
# 2               5           1
# 3               4           1
# 4               5           1
# 5               5           2
# 6               5           2
# 7               4           2
# 8               5           2
# 9               3           1
# 10              4           1

# %%
bk.loc[11:20,("Needle Stick Injuries","Occupation","Annual Income")]
# Out:
#     Needle Stick Injuries  Occupation  Annual Income
# 11                   4.75           1              4
# 12                   1.75           1              2
# 13                   4.00           1              3
# 14                   4.50           1              4
# 15                   5.00           2              5
# 16                   3.75           2              5
# 17                   1.00           2              1
# 18                   4.00           2              4
# 19                   1.75           2              1
# 20                   4.50           2              4

# %%
bk.drop(["Annual Income","Adherence to Safety Protocols","Availability of Safety Equipment","Knowledge and Training on Needle Stick Injury Prevention"],axis=1)
# Out:
#     Gender  Age  Occupation  Needle Stick Injuries  Work Environment Factors
# 0        2    2           2                   4.25                      4.75
# 1        1    3           1                   3.75                      3.75
# 2        2    1           1                   4.00                      4.00
# 3        2    2           1                   4.25                      4.00
# 4        1    2           1                   4.75                      4.25
# ..     ...  ...         ...                    ...                       ...
# 95       1    2           1                   2.00                      3.50
# 96       1    3           2                   4.00                      4.00
# 97       1    2           2                   5.00                      4.75
# 98       2    1           2                   3.00                      3.00
# 99       2    2           2                   5.00                      5.00
#
# [100 rows x 5 columns]

# %%
bk.drop("Knowledge and Training on Needle Stick Injury Prevention",axis=1)
# Out:
#     Gender  Age  Occupation  Annual Income  Needle Stick Injuries  \
# 0        2    2           2              3                   4.25
# 1        1    3           1              5                   3.75
# 2        2    1           1              5                   4.00
# 3        2    2           1              4                   4.25
# 4        1    2           1              5                   4.75
# ..     ...  ...         ...            ...                    ...
# 95       1    2           1              5                   2.00
# 96       1    3           2              4                   4.00
# 97       1    2           2              5                   5.00
# 98       2    1           2              3                   3.00
# 99       2    2           2              5                   5.00
#
#     Availability of Safety Equipment  Adherence to Safety Protocols  \
# 0                               4.00                           4.00
# ...

# %%
bk.drop([10,11,12,13,14,15],axis = 0)
# Out:
#     Gender  Age  Occupation  Annual Income  Needle Stick Injuries  \
# 0        2    2           2              3                   4.25
# 1        1    3           1              5                   3.75
# 2        2    1           1              5                   4.00
# 3        2    2           1              4                   4.25
# 4        1    2           1              5                   4.75
# ..     ...  ...         ...            ...                    ...
# 95       1    2           1              5                   2.00
# 96       1    3           2              4                   4.00
# 97       1    2           2              5                   5.00
# 98       2    1           2              3                   3.00
# 99       2    2           2              5                   5.00
#
#     Knowledge and Training on Needle Stick Injury Prevention  \
# 0                                                4.75
# 1                                                4.00
# ...

# %%
bk.head(20)
# Out:
#     Gender  Age  Occupation  Annual Income  Needle Stick Injuries  \
# 0        2    2           2              3                   4.25
# 1        1    3           1              5                   3.75
# 2        2    1           1              5                   4.00
# 3        2    2           1              4                   4.25
# 4        1    2           1              5                   4.75
# 5        1    3           2              5                   4.25
# 6        1    2           2              5                   4.00
# 7        2    1           2              4                   3.00
# 8        2    2           2              5                   4.25
# 9        2    2           1              3                   3.00
# 10       2    2           1              4                   4.50
# 11       2    2           1              4                   4.75
# 12       2    2           1              2                   1.75
# ...

# %%
df = bk.drop([10,11,12,13,14,15],axis = 0)
df
# Out:
#     Gender  Age  Occupation  Annual Income  Needle Stick Injuries  \
# 0        2    2           2              3                   4.25
# 1        1    3           1              5                   3.75
# 2        2    1           1              5                   4.00
# 3        2    2           1              4                   4.25
# 4        1    2           1              5                   4.75
# ..     ...  ...         ...            ...                    ...
# 95       1    2           1              5                   2.00
# 96       1    3           2              4                   4.00
# 97       1    2           2              5                   5.00
# 98       2    1           2              3                   3.00
# 99       2    2           2              5                   5.00
#
#     Knowledge and Training on Needle Stick Injury Prevention  \
# 0                                                4.75
# 1                                                4.00
# ...

# %%
df.head(20)
# Out:
#     Gender  Age  Occupation  Annual Income  Needle Stick Injuries  \
# 0        2    2           2              3                   4.25
# 1        1    3           1              5                   3.75
# 2        2    1           1              5                   4.00
# 3        2    2           1              4                   4.25
# 4        1    2           1              5                   4.75
# 5        1    3           2              5                   4.25
# 6        1    2           2              5                   4.00
# 7        2    1           2              4                   3.00
# 8        2    2           2              5                   4.25
# 9        2    2           1              3                   3.00
# 16       2    2           2              5                   3.75
# 17       2    2           2              1                   1.00
# 18       2    2           2              4                   4.00
# ...

# %%
bk.max()
# Out:
# Gender                                                      2.0
# Age                                                         5.0
# Occupation                                                  3.0
# Annual Income                                               5.0
# Needle Stick Injuries                                       5.0
# Knowledge and Training on Needle Stick Injury Prevention    5.0
# Availability of Safety Equipment                            5.0
# Adherence to Safety Protocols                               5.0
# Work Environment Factors                                    5.0
# dtype: float64

# %%
bk.min()
# Out:
# Gender                                                      1.0
# Age                                                         1.0
# Occupation                                                  1.0
# Annual Income                                               1.0
# Needle Stick Injuries                                       1.0
# Knowledge and Training on Needle Stick Injury Prevention    0.5
# Availability of Safety Equipment                            0.5
# Adherence to Safety Protocols                               1.0
# Work Environment Factors                                    0.5
# dtype: float64

# %%
bk.mean()
# Out:
# Gender                                                      1.5400
# Age                                                         2.1900
# Occupation                                                  1.6800
# Annual Income                                               3.7200
# Needle Stick Injuries                                       3.7550
# Knowledge and Training on Needle Stick Injury Prevention    3.6600
# Availability of Safety Equipment                            3.6575
# Adherence to Safety Protocols                               3.7225
# Work Environment Factors                                    3.7475
# dtype: float64

# %%
bk.median()
# Out:
# Gender                                                      2.0
# Age                                                         2.0
# Occupation                                                  2.0
# Annual Income                                               4.0
# Needle Stick Injuries                                       4.0
# Knowledge and Training on Needle Stick Injury Prevention    4.0
# Availability of Safety Equipment                            4.0
# Adherence to Safety Protocols                               4.0
# Work Environment Factors                                    4.0
# dtype: float64

# %%
def half(s):
    return 0.5*s

# %%
bk[['Annual Income','Occupation']].apply(half)
# Out:
#     Annual Income  Occupation
# 0             1.5         1.0
# 1             2.5         0.5
# 2             2.5         0.5
# 3             2.0         0.5
# 4             2.5         0.5
# ..            ...         ...
# 95            2.5         0.5
# 96            2.0         1.0
# 97            2.5         1.0
# 98            1.5         1.0
# 99            2.5         1.0
#
# [100 rows x 2 columns]

# %%
def double(s):
    return 2*s

# %%
bk[['Annual Income']].apply(double)
# Out:
#     Annual Income
# 0               6
# 1              10
# 2              10
# 3               8
# 4              10
# ..            ...
# 95             10
# 96              8
# 97             10
# 98              6
# 99             10
#
# [100 rows x 1 columns]

# %% [markdown]
# Done pandas library. ALHAMDULILLAH
